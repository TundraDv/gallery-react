# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
import json
import re

# %%
URL_OF_THE_WEBSITE = 'https://unsplash.com/s/photos/golden-gate?license=free'

# %%
driver = webdriver.Chrome()
driver.get(URL_OF_THE_WEBSITE)
# Click the "Load more" button until it is no longer available
load_more_button_selector = 'button.LaaWe.Qzy6N.ogSND.ZR5jm.cs1e4.ibgtd.v2BPu.mP89P.szXtT.wACgf.ZR5jm'
scroll_pause_time = 5  # Adjust based on your internet speed

while True:
    try:
        time.sleep(15)
        load_more_button = driver.find_element(By.XPATH, '//*[@id="app"]/div/div[1]/div/div[2]/div[4]/div[3]/button')
        load_more_button.click()
    except Exception as e:
        print(f"No more 'Load more' button found: {e}")
        break

# Scroll to the bottom of the page to load dynamic content
last_height = driver.execute_script("return document.body.scrollHeight")

n_scrolls = 15
for i in range(n_scrolls):
    time.sleep(scroll_pause_time)
    # Scroll down to the bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load the page

time.sleep(2)

# Get the page source and parse it with BeautifulSoup
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'html.parser')


all_data = []

# Find and process the desired elements
figures = soup.find_all('figure', itemprop='image')
for figure in figures:
    title = figure.get('title', None)
    
    a_user = figure.find('a', class_='BkSVh FEdrY SfGU7 ZR5jm jQEvX ZR5jm')
    div_teuli = soup.find('div', class_='TeuLI')

    if a_user:
        author = a_user.get_text(strip=True)
    else:
        author = None
    
    img_user = figure.find('img', class_='Lg6wf')
    if img_user:
        src_user = img_user.get('src')
        base_url_user = re.match(r'https://[^?]+', src_user).group(0)
    else:
        base_url_user = None

    img_post = figure.find('img', class_='ApbSI z1piP vkrMA')
    if img_post:
        src_post = img_post.get('src')
        base_url_post = re.match(r'https://[^?]+', src_post).group(0)
    else:
        base_url_post = None

    a_tags = figure.find_all('a', class_='VyS40 GcCli p4rnw')
    if a_tags:
        all_tags = [a.get_text(strip=True) for a in a_tags]
    else:
        all_tags = []
    
    print(title, author, base_url_user, all_tags, base_url_post)
    data = {
        "img": base_url_post,
        "title": title,
        "author": author,
        "imgUser": base_url_user,
        "tags": all_tags
    }
    all_data.append(data)

with open('data_unsplash.json', 'w') as file:
    json.dump(all_data, file, indent=2)

# Close the WebDriver
driver.quit()
# Out:
# No more 'Load more' button found: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="app"]/div/div[1]/div/div[2]/div[4]/div[3]/button"}
#   (Session info: chrome=126.0.6478.128); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7D294EEB2+31554]
# 	(No symbol) [0x00007FF7D28C7EE9]
# 	(No symbol) [0x00007FF7D278872A]
# 	(No symbol) [0x00007FF7D27D8434]
# 	(No symbol) [0x00007FF7D27D853C]
# 	(No symbol) [0x00007FF7D281F6A7]
# 	(No symbol) [0x00007FF7D27FD06F]
# 	(No symbol) [0x00007FF7D281C977]
# 	(No symbol) [0x00007FF7D27FCDD3]
# 	(No symbol) [0x00007FF7D27CA33B]
# 	(No symbol) [0x00007FF7D27CAED1]
# 	GetHandleVerifier [0x00007FF7D2C58B2D+3217341]
# 	GetHandleVerifier [0x00007FF7D2CA5AF3+3532675]
# 	GetHandleVerifier [0x00007FF7D2C9B0F0+3489152]
# 	GetHandleVerifier [0x00007FF7D29FE786+750614]
# ...

# %% [markdown]
# it still does weird stuff but it works

# %%
soup = BeautifulSoup(page_source, 'html.parser')
figures = soup.find_all('figure', itemprop='image')
for figure in figures:
  title = figure.get('title', None)
  a_user = figure.find('a', class_='OQSsT SfGU7 KELxP OUWB8 SfGU7')
  if a_user:
    name = a_user.get_text(strip=True)
    href = a_user.get('href')
  img_user = figure.find('img', class_='Lg6wf')
  if img_user:
    src_user = img_user.get('src')
  base_url_user = re.match(r'https://[^?]+', src_user).group(0)
  #Main image
  img_post = figure.find('img', class_='ApbSI z1piP vkrMA')
  if img_post:
    src_post = img_post.get('src')
  base_url_post = re.match(r'https://[^?]+', src_post).group(0)
  a_tags = figure.find_all('a', class_='VyS40 GcCli p4rnw')
  all_tags = [a.get_text(strip=True) for a in a_tags]
  print(title, name, base_url_user, all_tags, base_url_post)
# Out:
# None Joshua Earle https://images.unsplash.com/profile-1706811618759-2971389ba999image ['san francisco', 'baker beach', 'beach landscape'] https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a
# None Casey Horner https://images.unsplash.com/profile-1502669002421-a8d274ad2897 ['usa', 'famous view', 'san francisco bay area'] https://plus.unsplash.com/premium_photo-1688430696418-a3ccf3a4f7e2
# None Casey Horner https://images.unsplash.com/profile-1720185996047-e04ea31f7227image ['landmark', 'HD Water Wallpapers', 'francisco'] https://images.unsplash.com/photo-1719858403473-303b271f154b
# None Casey Horner https://images.unsplash.com/profile-1720185996047-e04ea31f7227image ['HD City Wallpapers', 'transportation', 'bay'] https://images.unsplash.com/photo-1719858403364-83f7442a197e
# None Casey Horner https://images.unsplash.com/profile-1615309704582-c0ed6450db71image ['suspension bridge', 'drone view', 'goldengate'] https://images.unsplash.com/photo-1481991990414-7802ae5de1e0
# ...

# %% [markdown]
# <figure data-masonryposition="1" data-test="photo-grid-masonry-figure" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject"><div class="MblTp"><div><div class="fWieE"><div class="aD8H3"><a class="Prxeh" href="/photos/a-view-of-the-golden-gate-bridge-from-the-beach-dL2du5DXHeA" itemprop="contentUrl" title="a view of the golden gate bridge from the beach"><div class="HcSeS"><div class="O9fwi" style="background-color:#EFEFEF"></div><img class="O9fwi" src="..."/><img alt="a view of the golden gate bridge from the beach" class="ApbSI z1piP vkrMA" data-perf="eager-loaded-img" data-test="photo-grid-masonry-img" itemprop="thumbnailUrl" sizes="(min-width: 1335px) 410.6666666666667px, (min-width: 992px) calc(calc(100vw - 88px) / 3), (min-width: 768px) calc(calc(100vw - 64px) / 2), 100vw" src="https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?fm=jpg&amp;q=60&amp;w=3000&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D" srcset="https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=100&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 100w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=200&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 200w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=300&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 300w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=400&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 400w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=500&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 500w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=600&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 600w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=700&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 700w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=800&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 800w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=900&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 900w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=1000&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 1000w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=1200&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 1200w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=1400&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 1400w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=1600&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 1600w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=1800&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 1800w, https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?w=2000&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixlib=rb-4.0.3&amp;ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Z29sZGVuJTIwZ2F0ZXxlbnwwfHwwfHx8MA%3D%3D 2000w" style="aspect-ratio:4001 / 6000"/></div></a><div class="wbgEz C_yva"><div class="ZuV6q"><div class="c8Gtq PfA9b"></div><div class="SBwXb Azcq0"><div class="OkMtd"><div><a class="GY6KW ZRFSe SfGU7 bNiFq" href="/plus?referrer=%2Fphotos%2Fa-view-of-the-golden-gate-bridge-from-the-beach-dL2du5DXHeA"><svg aria-hidden="false" class="xJdt3" height="24" style="flex-shrink: 0;" version="1.1" viewbox="0 0 24 24" width="24"><desc lang="en-US">Plus sign for Unsplash+</desc><path d="M11.281 8.3H8.156V3.125L11.281 1v7.3Zm.316 4.05H4.955V
"><desc lang="en-US">A lock</desc><path d="M19 11h-1.5V7.5C17.5 4.5 15 2 12 2S6.5 4.5 6.5 7.5V11H5c-.6 0-1 .4-1 1v9c0 .6.4 1 1 1h14c.6 0 1-.4 1-1v-9c0-.6-.4-1-1-1ZM8.5 7.5C8.5 5.6 10.1 4 12 4s3.5 1.6 3.5 3.5V11h-7V7.5Z"></path></svg>Download</a></div></div></div></div></div></div></div></div></div><div><div class="zDHt2 N9mmz"><a class="VyS40 GcCli p4rnw" href="/s/photos/san-francisco" title="san francisco images">san francisco</a><a class="VyS40 GcCli p4rnw" href="/s/photos/baker-beach" title="baker beach images">baker beach</a><a class="VyS40 GcCli p4rnw" href="/s/photos/beach-landscape" title="beach landscape images">beach landscape</a></div></div></div></figure>
# san francisco
# baker beach
# beach landscape

# %% [markdown]
# figure data-masonryposition="1" data-test="photo-grid-masonry-figure" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject"><div class="MblTp"><div><div class="fWieE"><div class="aD8H3"><a class="Prxeh" href="/photos/a-view-of-the-golden-gate-bridge-from-the-beach-dL2du5DXHeA" itemprop="contentUrl" title="a view of the golden gate bridge from the beach"><div class="HcSeS"><div class="O9fwi" style="background-color:#EFEFEF"></div>
#
# <img class="O9fwi" src="..."/>
#
# <img alt="a view of the golden gate bridge from the beach" class="ApbSI z1piP vkrMA" data-perf="eager-loaded-img" data-test="photo-grid-masonry-img" itemprop="thumbnailUrl" sizes="(min-width: 1335px) 410.6666666666667px, (min-width: 992px) calc(calc(100vw - 88px) / 3), (min-width: 768px) calc(calc(100vw - 64px) / 2), 100vw" src="https://plus.unsplash.com/premium_photo-1673002094407-a72547fa791a?fm=jpg&amp;q=60&amp;w=3000&amp;ixlib=rb-4.0.3&amp;style="aspect-ratio:4001 / 6000"/></div></a><div class="wbgEz C_yva"><div class="ZuV6q"><div class="c8Gtq PfA9b"></div><div class="SBwXb Azcq0"><div class="OkMtd"><div><a class="GY6KW ZRFSe SfGU7 bNiFq" href="/plus?referrer=%2Fphotos%2Fa-view-of-the-golden-gate-bridge-from-the-beach-dL2du5DXHeA"><svg aria-hidden="false" class="xJdt3" height="24" style="flex-shrink: 0;" version="1.1" viewbox="0 0 24 24" width="24"><desc lang="en-US">Plus sign for Unsplash+</desc><path d="M11.281 8.3H8.156V3.125L11.281 1v7.3Zm.316 4.05H4.955V7.868L1.5 10.636v4.55h6.656V22h4.713l3.552-2.84h-4.824v-6.81Zm4.24 0v2.835h4.587l2.911-2.834h-7.497Z"></path></svg></a></div><div class="PlYNe PfA9b"><button class="Ksjvc jPvw6 bNiFq NONej Qzy6N ogSND ZR5jm cs1e4 xMiih ZR5jm GcCli UvzWP mP89P szXtT" title="Like this image" type="button"><svg aria-hidden="false" class="ApMeQ" height="24" style="flex-shrink: 0;" version="1.1" viewbox="0 0 24 24" width="24"><desc lang="en-US">A heart</desc>
#
